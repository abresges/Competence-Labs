# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
dtpre=pd.read_excel('PRE-POST.xlsx', sheet_name='DT PRE')
print(dtpre)
# Out:
#     Tabelle 1 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4    Unnamed: 5  \
# 0    v_SWE1_1   v_SWE1_2   v_SWE1_3   v_SWE1_4   v_SWE1_5  v_ERBSE_L_01
# 1           3          3          4          2          3             2
# 2           3          3          3          4          4             3
# 3           3          3          3          3          3             2
# 4           3          3          3          3          2             2
# 5           3          2          2          2          3             4
# 6           4          3          2          3          4             2
# 7           3          3          3          2          3             3
# 8           4          3          3          4          4             4
# 9           3          3          3          3          3             2
# 10          3          3          2          3          3             3
# 11          3          3          2          3          3             3
# ...

# %%
dtpost=pd.read_excel('PRE-POST.xlsx', sheet_name='DT POST')
print(dtpost)
# Out:
#     Tabelle 1 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4    Unnamed: 5  \
# 0    v_SWE1_1   v_SWE1_2   v_SWE1_3   v_SWE1_4   v_SWE1_5  v_ERBSE_L_01
# 1           4          4          4          3          4             4
# 2           3          3          3          3          3             2
# 3           3          4          3          3          4             3
# 4           3          3          3          3          3             2
# 5           4          3          3          4          4             3
# 6           3          3          3          2          3             4
# 7           3          3          3          3          3             3
# 8           3          3          3          3          4             3
# 9           3          3          3          2          2             3
# 10          4          4          3          3          4             4
# 11          4          4          3          3          3             4
# ...

# %%
pre=dtpre.iloc[0:4, 5:10]
print(pre)
# Out:
#      Unnamed: 5    Unnamed: 6    Unnamed: 7    Unnamed: 8    Unnamed: 9
# 0  v_ERBSE_L_01  v_ERBSE_L_02  v_ERBSE_L_03  v_ERBSE_L_04  v_ERBSE_L_05
# 1             2             3             3             4             3
# 2             3             4             4             4             3
# 3             2             4             3             4             4

# %%
plt.hist(pre)
# Out:
# ([array([ 5.,  0.,  0.,  0.,  0., 11.,  0.,  0.,  0.,  4.]),
#   array([ 2.,  0.,  0.,  0.,  0., 12.,  0.,  0.,  0.,  6.]),
#   array([8., 0., 0., 0., 0., 8., 0., 0., 0., 4.])],
#  array([2.0, 2.2, 2.4, 2.6, 2.8, 3.0, 3.2, 3.4000000000000004, 3.6, 3.8,
#         4.0], dtype=object),
#  <a list of 3 Lists of Patches objects>)

# %%
post=dtpost.iloc[0:4, 5:10]
print(post)
# Out:
#      Unnamed: 5    Unnamed: 6    Unnamed: 7    Unnamed: 8    Unnamed: 9
# 0  v_ERBSE_L_01  v_ERBSE_L_02  v_ERBSE_L_03  v_ERBSE_L_04  v_ERBSE_L_05
# 1             4             4             4             4             4
# 2             2             3             4             3             3
# 3             3             4             3             4             4

# %%
tau=post-pre
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in na_op(x, y)
#    1496         try:
# -> 1497             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1498         except TypeError:
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     204     if use_numexpr:
# --> 205         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     206     return _evaluate_standard(op, op_str, a, b)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     119     if result is None:
# --> 120         result = _evaluate_standard(op, op_str, a, b)
#     121
#
# ...
